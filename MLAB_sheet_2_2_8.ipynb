# %%
import numpy as np
from sklearn import svm, datasets
from sklearn.model_selection import GridSearchCV

# %%
def make_image(f):
    data = np.frombuffer(f.read (), np.uint8 , offset=16)
    data = data.reshape (-1, 28, 28)
    return data/np.float32 (256)

def make_lable(f):
    return np.frombuffer(f.read (), np.uint8 , offset=8)

X_train = make_image(open('/Users/puester/Desktop/MNIST/train-images-idx3-ubyte', 'rb'))
y_train = make_lable(open('/Users/puester/Desktop/MNIST/train-labels-idx1-ubyte', 'rb'))
X_test = make_image(open('/Users/puester/Desktop/MNIST/t10k-images-idx3-ubyte', 'rb'))
y_test = make_lable(open('/Users/puester/Desktop/MNIST/t10k-labels-idx1-ubyte', 'rb'))

# %%
parameters = {'kernel':('linear', 'rbf'), 'C':[1, 10,100]}
for gamma in [.1,.01,.001]:
    svc = svm.SVC(gamma)                       # scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
    gscv = GridSearchCV(svc, parameters, cv=5) # scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html
    gscv.fit(X_train, y_train)
    sorted(clf.cv_results_.keys())
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_validation.py:542: FutureWarning: From version 0.22, errors during fit will result in a cross validation score of NaN by default. Use error_score='raise' if you want an exception raised or error_score=np.nan to adopt the behavior from version 0.22.
#   FutureWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-f6c784a5182b> in <module>()
#       3     svc = svm.SVC(gamma)
#       4     gscv = GridSearchCV(svc, parameters, cv=5)
# ----> 5     gscv.fit(X_train, y_train)
#       6     sorted(clf.cv_results_.keys())
#
# /anaconda3/lib/python3.6/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     720                 return results_container[0]
#     721
# --> 722             self._run_search(evaluate_candidates)
#     723
# ...
